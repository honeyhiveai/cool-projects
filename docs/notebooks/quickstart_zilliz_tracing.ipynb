# %%
# !pip install openai pymilvus honeyhive
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.61.1)
# Requirement already satisfied: pymilvus in /usr/local/lib/python3.11/dist-packages (2.5.4)
# Requirement already satisfied: honeyhive in /usr/local/lib/python3.11/dist-packages (0.2.31)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (75.1.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (4.25.6)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: milvus-lite>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (2.4.11)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (2.32.3)
# Requirement already satisfied: uplink>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (0.9.7)
# Requirement already satisfied: traceloop-sdk<=0.30,>=0.18.2 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (0.30.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (0.9.0)
# Requirement already satisfied: dataclasses-json>=0.6.7 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (0.6.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (6.0.2)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from honeyhive) (13.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json>=0.6.7->honeyhive) (3.26.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->honeyhive) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.1->honeyhive) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->honeyhive) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->honeyhive) (2.18.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.4.6)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.2.18)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (3.1.5)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.27.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-alephalpha==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-anthropic==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-bedrock==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-chromadb==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-cohere==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-google-generativeai==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-groq==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-haystack==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-lancedb==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-langchain==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-llamaindex==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-marqo==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-milvus==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-mistralai==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-ollama==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-openai==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-pinecone==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-qdrant==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-replicate==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-requests<0.49,>=0.48b0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-sqlalchemy<0.49,>=0.48b0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<0.49,>=0.48b0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-together==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-transformers==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3<0.49,>=0.48b0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation-vertexai==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-watsonx==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-weaviate==0.30.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.30.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.27.0 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai==0.4.1 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.4.1)
# Requirement already satisfied: posthog<4,>3.0.2 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (3.14.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from traceloop-sdk<=0.30,>=0.18.2->honeyhive) (8.5.0)
# Requirement already satisfied: opentelemetry-instrumentation<0.49,>=0.48b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-alephalpha==0.30.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions<0.49,>=0.48b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-alephalpha==0.30.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: anthropic>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-bedrock==0.30.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.46.0)
# Requirement already satisfied: inflection<0.6.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-llamaindex==0.30.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.5.1)
# Requirement already satisfied: tiktoken<1,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-openai==0.30.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.9.0->honeyhive) (1.0.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from uplink>=0.0.2->honeyhive) (1.17.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from uplink>=0.0.2->honeyhive) (4.1.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated<2.0.0,>=1.2.14->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->honeyhive) (0.1.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json>=0.6.7->honeyhive) (24.2)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<2.0.0,>=1.27.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.26.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.67.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.26.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.26.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.27.0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-requests<0.49,>=0.48b0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (0.48b0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog<4,>3.0.2->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4,>3.0.2->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api<2.0.0,>=1.27.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (3.21.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.6.0->opentelemetry-instrumentation-openai==0.30.0->traceloop-sdk<=0.30,>=0.18.2->honeyhive) (2024.11.6)

# %%
from openai import OpenAI
from pymilvus import MilvusClient
from honeyhive.tracer import HoneyHiveTracer
from honeyhive.tracer.custom import trace

# Initialize HoneyHive Tracer
HoneyHiveTracer.init(
    api_key="Your HoneyHive key",
    project="name of your project",
)

# Initialize OpenAI client
openai_client = OpenAI(api_key="your OpenAI key")

# Initialize Milvus client
milvus_client = MilvusClient("milvus_demo.db")  # Using Milvus Lite for demo

def embed_text(text):
    """Generate embeddings using OpenAI's text-embedding-ada-002 model"""
    res = openai_client.embeddings.create(
        model="text-embedding-ada-002",
        input=text
    )
    return res.data[0].embedding

@trace(
    config={
        "collection_name": "demo_collection",
        "dimension": 1536,  # text-embedding-ada-002 dimension
    }
)
def setup_collection():
    """Set up Milvus collection with tracing"""
    # Drop collection if it exists
    if milvus_client.has_collection(collection_name="demo_collection"):
        milvus_client.drop_collection(collection_name="demo_collection")

    # Create new collection
    milvus_client.create_collection(
        collection_name="demo_collection",
        dimension=1536  # text-embedding-ada-002 dimension
    )

@trace(
    config={
        "embedding_model": "text-embedding-ada-002"
    }
)
def insert_documents(documents):
    """Insert documents with tracing"""
    vectors = [embed_text(doc) for doc in documents]
    data = [
        {
            "id": i,
            "vector": vectors[i],
            "text": documents[i],
            "subject": "general"
        }
        for i in range(len(vectors))
    ]

    res = milvus_client.insert(
        collection_name="demo_collection",
        data=data
    )
    return res

@trace(
    config={
        "embedding_model": "text-embedding-ada-002",
        "top_k": 3
    }
)
def search_similar_documents(query, top_k=3):
    """Search for similar documents with tracing"""
    query_vector = embed_text(query)

    results = milvus_client.search(
        collection_name="demo_collection",
        data=[query_vector],
        limit=top_k,
        output_fields=["text", "subject"]
    )

    return [match["entity"]["text"] for match in results[0]]

@trace(
    config={
        "model": "gpt-4",
        "prompt": "You are a helpful assistant"
    }
)
def generate_response(context, query):
    """Generate response using OpenAI with tracing"""
    prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
    response = openai_client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

@trace()
def rag_pipeline(query):
    """Complete RAG pipeline with tracing"""
    # Get relevant documents
    relevant_docs = search_similar_documents(query)
    # Generate response
    response = generate_response("\n".join(relevant_docs), query)
    return response

def main():
    # Sample documents
    documents = [
        "Artificial intelligence was founded as an academic discipline in 1956.",
        "Machine learning is a subset of artificial intelligence.",
        "Deep learning is a type of machine learning based on artificial neural networks.",
        "Natural Language Processing (NLP) is a branch of AI that helps computers understand human language.",
    ]

    # Set up collection
    setup_collection()

    # Insert documents
    print("Inserting documents...")
    insert_documents(documents)

    # Test RAG pipeline
    query = "What is the relationship between AI and machine learning?"
    print(f"\nQuery: {query}")
    response = rag_pipeline(query)
    print(f"Response: {response}")

if __name__ == "__main__":
    main()
# Out:
# Traceloop exporting traces to https://api.honeyhive.ai/opentelemetry authenticating with bearer token
#
# Inserting documents...
#
# Query: What is the relationship between AI and machine learning?
# Response: AI, or Artificial Intelligence, is a broader concept of machines being able to carry out tasks in a way that we would consider "smart". Machine Learning is a subset or an application of AI that focuses on the ability of machines to receive a set of data and learn for themselves, changing algorithms as they learn more about the information they are processing. In other words, all Machine Learning is AI, but not all AI involves Machine Learning.
